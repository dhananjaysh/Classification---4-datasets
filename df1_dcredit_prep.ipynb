# %%
############ DATA NOTES ############

# name: default credit
# features: characteristics of client given credit
# target: predicts the "default" (credibility) of client, whether yes or no

# important metric: recall should be high, no missed uncredible clients (low false negatives)

# %%
import df_utils as utils

# %%
############ CONFIGURATION ############

# list desired settings
data_config = {
    "dataset": "default_credit",
    "index": "ID",
    "target": "default",
    "imbalanced": True,
    "has_test": False,
    "remove_features": True,
}

# %%
# import data set
(data, _) = utils.import_data(data_config["dataset"], has_test=data_config["has_test"], raw=True)
# Out:
# importing from: data\data_raw\default_credit.csv

# %%
############ PRE-PROCESSING ############

# check data types
print(data.dtypes)
# Out:
# ID           int64
# LIMIT_BAL    int64
# SEX          int64
# EDUCATION    int64
# MARRIAGE     int64
# AGE          int64
# PAY_0        int64
# PAY_2        int64
# PAY_3        int64
# PAY_4        int64
# PAY_5        int64
# PAY_6        int64
# BILL_AMT1    int64
# BILL_AMT2    int64
# BILL_AMT3    int64
# BILL_AMT4    int64
# BILL_AMT5    int64
# BILL_AMT6    int64
# PAY_AMT1     int64
# PAY_AMT2     int64
# PAY_AMT3     int64
# PAY_AMT4     int64
# PAY_AMT5     int64
# PAY_AMT6     int64
# default      int64
# dtype: object

# %%
# set data index
data = utils.set_data_index(data, data_config["index"])

# %%
############ VISUALIZATION ############

# get quick overview of the data structure
display(data)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# 5          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996     220000    1          3         1   39      0      0      0      0
# 29997     150000    1          3         2   43     -1     -1     -1     -1
# 29998      30000    1          2         2   37      4      3      2     -1
# 29999      80000    1          3         1   41      1     -1      0      0
# 30000      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID            ...
# 1         -2  ...          0          0          0         0       689
# 2          0  ...       3272       3455       3261         0      1000
# 3          0  ...      14331      14948      15549      1518      1500
# 4          0  ...      28314      28959      29547      2000      2019
# 5          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29996      0  ...      88004      31237      15980      8500     20000
# 29997      0  ...       8979       5190          0      1837      3526
# 29998      0  ...      20878      20582      19357         0         0
# 29999      0  ...      52774      11855      48944     85900      3409
# 30000      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ID
# 1             0         0         0         0        1
# 2          1000      1000         0      2000        1
# 3          1000      1000      1000      5000        0
# 4          1200      1100      1069      1000        0
# 5         10000      9000       689       679        0
# ...         ...       ...       ...       ...      ...
# 29996      5003      3047      5000      1000        0
# 29997      8998       129         0         0        0
# 29998     22000      4200      2000      3100        1
# 29999      1178      1926     52964      1804        1
# 30000      1430      1000      1000      1000        1
#
# [30000 rows x 24 columns]

# %%
# get quick overview of data values
utils.get_summary(data)
# Out:
#            dtype  unique  missing  duplicate
# LIMIT_BAL  int64      81        0         35
# SEX        int64       2        0         35
# EDUCATION  int64       7        0         35
# MARRIAGE   int64       4        0         35
# AGE        int64      56        0         35
# PAY_0      int64      11        0         35
# PAY_2      int64      11        0         35
# PAY_3      int64      11        0         35
# PAY_4      int64      11        0         35
# PAY_5      int64      10        0         35
# PAY_6      int64      10        0         35
# BILL_AMT1  int64   22723        0         35
# BILL_AMT2  int64   22346        0         35
# BILL_AMT3  int64   22026        0         35
# BILL_AMT4  int64   21548        0         35
# BILL_AMT5  int64   21010        0         35
# BILL_AMT6  int64   20604        0         35
# PAY_AMT1   int64    7943        0         35
# PAY_AMT2   int64    7899        0         35
# PAY_AMT3   int64    7518        0         35
# PAY_AMT4   int64    6937        0         35
# PAY_AMT5   int64    6897        0         35
# PAY_AMT6   int64    6939        0         35
# default    int64       2        0         35

# %%
# get quick overview of the numerical data distribution
data.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6       default
# count   30000.000000  30000.000000
# mean     5215.502567      0.221200
# std     17777.465775      0.415062
# min         0.000000      0.000000
# 25%       117.750000      0.000000
# 50%      1500.000000      0.000000
# 75%      4000.000000      0.000000
# max    528666.000000      1.000000
#
# [8 rows x 24 columns]

# %%
# get quick graphical overview of the numerical data distribution
utils.plot_numerical_data(data, data_config["target"])

# %%
# get a quick graphical overview of the categorical data distribution
utils.plot_categorical_data(data)

# %%
############ FEATURE SELECTION ############

# determine correlations between variables
utils.print_correlation_matrix(data)
# Out:
# <style type="text/css">
# #T_a31e3_row0_col0, #T_a31e3_row0_col1, #T_a31e3_row0_col2, #T_a31e3_row0_col3, #T_a31e3_row0_col4, #T_a31e3_row0_col5, #T_a31e3_row0_col6, #T_a31e3_row0_col7, #T_a31e3_row0_col8, #T_a31e3_row0_col9, #T_a31e3_row0_col10, #T_a31e3_row0_col11, #T_a31e3_row0_col12, #T_a31e3_row0_col13, #T_a31e3_row0_col14, #T_a31e3_row0_col15, #T_a31e3_row0_col16, #T_a31e3_row0_col17, #T_a31e3_row0_col18, #T_a31e3_row0_col19, #T_a31e3_row0_col20, #T_a31e3_row0_col21, #T_a31e3_row0_col22, #T_a31e3_row0_col23, #T_a31e3_row1_col1, #T_a31e3_row1_col2, #T_a31e3_row1_col3, #T_a31e3_row1_col4, #T_a31e3_row1_col5, #T_a31e3_row1_col6, #T_a31e3_row1_col7, #T_a31e3_row1_col8, #T_a31e3_row1_col9, #T_a31e3_row1_col10, #T_a31e3_row1_col11, #T_a31e3_row1_col12, #T_a31e3_row1_col13, #T_a31e3_row1_col14, #T_a31e3_row1_col15, #T_a31e3_row1_col16, #T_a31e3_row1_col17, #T_a31e3_row1_col18, #T_a31e3_row1_col19, #T_a31e3_row1_col20, #T_a31e3_row1_col21, #T_a31e3_row1_col22, #T_a31e3_row1_col23, #T_a31e3_row2_col2, #T_a31e3_row2_col3, #T_a31e3_row2_col4, #T_a31e3_row2_col5, #T_a31e3_row2_col6, #T_a31e3_row2_col7, #
7_col19, #T_a31e3_row7_col20, #T_a31e3_row7_col21, #T_a31e3_row7_col22, #T_a31e3_row7_col23, #T_a31e3_row8_col8, #T_a31e3_row8_col9, #T_a31e3_row8_col10, #T_a31e3_row8_col11, #T_a31e3_row8_col12, #T_a31e3_row8_col13, #T_a31e3_row8_col14, #T_a31e3_row8_col15, #T_a31e3_row8_col16, #T_a31e3_row8_col17, #T_a31e3_row8_col18, #T_a31e3_row8_col19, #T_a31e3_row8_col20, #T_a31e3_row8_col21, #T_a31e3_row8_col22, #T_a31e3_row8_col23, #T_a31e3_row9_col9, #T_a31e3_row9_col10, #T_a31e3_row9_col11, #T_a31e3_row9_col12, #T_a31e3_row9_col13, #T_a31e3_row9_col14, #T_a31e3_row9_col15, #T_a31e3_row9_col16, #T_a31e3_row9_col17, #T_a31e3_row9_col18, #T_a31e3_row9_col19, #T_a31e3_row9_col20, #T_a31e3_row9_col21, #T ...
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_a31e3_row1_col0, #T_a31e3_row6_col3, #T_a31e3_row11_col2, #T_a31e3_row17_col4, #T_a31e3_row23_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_a31e3_row2_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_a31e3_row2_col1, #T_a31e3_row13_col2, #T_a31e3_row23_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_a31e3_row3_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_a31e3_row3_col1, #T_a31e3_row11_col1, #T_a31e3_row12_col1, #T_a31e3_row21_col8, #T_a31e3_row21_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_a31e3_row3_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_a31e3_row4_col0, #T_a31e3_row20_col13, #T_a31e3_row21_col15 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_a31e3_row4_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_a31e3_row4_col2, #T_a31e3_row16_col5, #T_a31e3_row18_col16, #T_a31e3_row22_col12, #T_a31e3_row22_col14 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_a31e3_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a31e3_row5_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_a31e3_row5_col1, #T_a31e3_row8_col1, #T_a31e3_row18_col6, #T_a31e3_row20_col9, #T_a31e3_row21_col5, #T_a31e3_row22_col5, #T_a31e3_row23_col18, #T_a31e3_row23_col20 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a31e3_row5_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_a31e3_row5_col3, #T_a31e3_row12_col2, #T_a31e3_row18_col4, #T_a31e3_row20_col4, #T_a31e3_row20_col10, #T_a31e3_row21_col4, #T_a31e3_row22_col4 {

# %%
# drop highly correlated and redundant features
if data_config["remove_features"]:
    data = data.drop(columns=["BILL_AMT2"])  # directly related to "BILL_AMT1" and "BILL_AMT3"
    data = data.drop(columns=["BILL_AMT5"]) # directly related to "BILL_AMT4" and "BILL_AMT6"

list(data.columns)
# Out:
# ['LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'default']

# %%
# export data set
utils.export_data(data, data_config["dataset"], predict=False)
